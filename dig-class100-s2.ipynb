# %% [markdown]
# ## The Training
#
# ### 1st train
#
# Runs with data digit images only.
# The best model will be stored as "dig-s1-md-best.h5"
#
#
# ## The Model
#
# Used a the jomjol CNN-S1 network as small model.

# %%
########### Basic Parameters for Running: ################################
    
Training_Percentage = 0.2           
Epoch_Anz = 400                     # earlystopping, see model.fit
nb_classes = 100                     # move to 1. step
#input_shape = (32, 20,1)            # will be calculated
Batch_Size = 32
use_grayscale = False                # grayscale or rgb
output_dir = "output/" 
output_tmp_dir = "output/tmp/"
model_filename = "dig-class100-s2"

##########################################################################

from sklearn.model_selection import train_test_split
from b2n.data.ziffer import ziffer_data
from b2n.plotfunctions import *
from sklearn.utils import shuffle
import tensorflow as tf
from b2n.encodings.class_encoding import *
from b2n.augmentation.generator import *
from datetime import datetime
import sys

date_time = datetime.now().strftime("%Y%m%d-%H%M%S")
print("Tensorflow-Version: ", tf.__version__)
print("Python:", sys.version)


print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

#try:
#    # Disable all GPUS
#    tf.config.set_visible_devices([], 'GPU')
#    visible_devices = tf.config.get_visible_devices()
#    for device in visible_devices:
#        assert device.device_type != 'GPU'
#except:
#    # Invalid device or cannot modify virtual devices once initialized.
#    pass
# Out:
# Tensorflow-Version:  2.16.2
# Python: 3.11.14 | packaged by conda-forge | (main, Oct 22 2025, 22:56:31) [Clang 19.1.7 ]
# Num GPUs Available:  1

# %% [markdown]
# ## Load data
#
# Like the distillation network meter digits will be trained with font builded images.
#
# ### digit meter images
#
# The meter digits are all 0-9 ziffer_raw (https://github.com/jomjol/neural-network-autotrain-digital-counter/tree/main/ziffer_raw) and other collected data (used https://github.com/haverland/collectmeterdigits).
#
# ### Train and Test data
#
# For 1st train the digit meter will be used.
#
# ### digit meter spread
#
# The images of digit meters are collected and labeled by hand. So the image count of labels are differnt. The meter digit spread plot shows the count for each label.

# %%
xz_data, yz_data, fz_data = ziffer_data(input_dir='images')

# distribution
_, inverse = np.unique(yz_data, return_inverse=True)
ziffer_bincount = np.bincount(inverse)
plot_divergence(ziffer_bincount, "meter digits spread", nb_classes)


# Split train and validation data 
xz_train, yz_train = shuffle(xz_data, yz_data)
x_train, x_test, y_train, y_test = train_test_split(xz_train, yz_train, test_size=Training_Percentage)

input_shape=xz_train[0].shape
print(f"dataset x_train-size={len(xz_train)}")
plot_dataset(xz_train, yz_train)

print("test")

y_train = class_encoding(y_train, nb_classes)
y_test = class_encoding(y_test, nb_classes)
# Out:
# Ziffer data count:  27253
# dataset x_train-size=27253
# test

# %%
import numpy as np
from b2n.plotfunctions import plot_dataset_ds


preprocessing = tf.keras.Sequential([
        tf.keras.layers.RandomZoom([-.1, .1]),
        tf.keras.layers.RandomRotation((-0.02, 0.02)),
        tf.keras.layers.RandomContrast(0.1),
        tf.keras.layers.RandomBrightness(0.1),
        #tf.keras.layers.RandomTranslation(0.1, 0.1)
        ])

datagen = tf.data.Dataset.from_tensor_slices((x_train, y_train))
datagen = datagen.map(lambda x, y: (preprocessing(x), y),
		 num_parallel_calls=tf.data.AUTOTUNE)

# train data
print("Train data")
plot_dataset_ds(datagen)

# validation data
print("Validation data")
plot_dataset_ds(tf.data.Dataset.from_tensor_slices((x_test, y_test)))

train_iterator = datagen.cache().batch(Batch_Size).prefetch(tf.data.AUTOTUNE)
validation_iterator = tf.data.Dataset.from_tensor_slices((x_test, y_test)).cache().batch(Batch_Size).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-11-04 19:35:38.320326: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-11-04 19:35:38.320364: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-11-04 19:35:38.320368: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-11-04 19:35:38.320387: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-04 19:35:38.320400: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Train data
# 2025-11-04 19:35:38.630825: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# Validation data

# %% [markdown]
# ### Augmentation
# See augementation above for augmentation values.
# Standard augmentation of image generator is used plus inverting and noising images.
#
# The validation set is not augmentated. It uses only meter digit images for a real result how the model fits to meter digits.
# So the validation says more about the results and its easier to use a early stopping mechanism.

# %% [markdown]
# ### The Model
#
# Is an small EfficientNet like model with a dense output of 100 at top.

# %%
import tensorflow as tf
from b2n.models.distiller import Distiller
from b2n.models.effnet import Effnet
from b2n.models.cnn32 import *
from keras import backend as K

model = CNN_s2(input_shape, nb_classes, activation_top=None)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), 
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001), metrics = ["accuracy"])

model.summary()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tf217/lib/python3.11/site-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 32, 20, 3)      │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 20, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 20, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 5, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 214,000 (835.94 KB)
#  Trainable params: 213,674 (834.66 KB)
#  Non-trainable params: 326 (1.27 KB)

# %% [markdown]
# ### The Training
#
# Standard training of the model with complete dataset.
#
# The ModelCheckpoint helps to keep the best model.

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from b2n.plotfunctions import plot_acc_loss, predict_meter_digits
tf.config.run_functions_eagerly(True)

# Early stopping is the standard way to prevent overfitting. The Epoch_Anz should not be reached any time.
# It restores the best weights automatically, after stopping the training
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=25, verbose=0,  restore_best_weights=True)
# Reduce learning rate when a metric has stopped improving. Smaller learning rates often lead to better results.
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.85, patience=3, min_lr=1e-5, verbose=0)
history = model.fit(train_iterator, 
                validation_data=validation_iterator, 
                batch_size=Batch_Size, 
                epochs = Epoch_Anz,
                callbacks=[earlystop, reduce_lr],
                verbose=2)


model.export(output_tmp_dir + model_filename)

plot_acc_loss(history, "Trainingsresults")
# Out:
# Epoch 1/400
# 682/682 - 74s - 109ms/step - accuracy: 0.1663 - loss: 3.5433 - val_accuracy: 0.5869 - val_loss: 1.3041 - learning_rate: 0.0010
# Epoch 2/400
# 682/682 - 68s - 99ms/step - accuracy: 0.4885 - loss: 1.6423 - val_accuracy: 0.7494 - val_loss: 0.7130 - learning_rate: 0.0010
# Epoch 3/400
# 682/682 - 68s - 100ms/step - accuracy: 0.6061 - loss: 1.2074 - val_accuracy: 0.7819 - val_loss: 0.5854 - learning_rate: 0.0010
# Epoch 4/400
# 682/682 - 66s - 97ms/step - accuracy: 0.6570 - loss: 1.0293 - val_accuracy: 0.8107 - val_loss: 0.5214 - learning_rate: 0.0010
# Epoch 5/400
# 682/682 - 66s - 96ms/step - accuracy: 0.6834 - loss: 0.9260 - val_accuracy: 0.8129 - val_loss: 0.4907 - learning_rate: 0.0010
# Epoch 6/400
# 682/682 - 67s - 98ms/step - accuracy: 0.7038 - loss: 0.8646 - val_accuracy: 0.8143 - val_loss: 0.4884 - learning_rate: 0.0010
# Epoch 7/400
# 682/682 - 65s - 95ms/step - accuracy: 0.7155 - loss: 0.8217 - val_accuracy: 0.8211 - val_loss: 0.4677 - learning_rate: 0.0010
# Epoch 8/400
# 682/682 - 66s - 96ms/step - accuracy: 0.7303 - loss: 0.7784 - val_accuracy: 0.8287 - val_loss: 0.4431 - learning_rate: 0.0010
# Epoch 9/400
# 682/682 - 65s - 96ms/step - accuracy: 0.7393 - loss: 0.7406 - val_accuracy: 0.8354 - val_loss: 0.4233 - learning_rate: 0.0010
# Epoch 10/400
# 682/682 - 64s - 94ms/step - accuracy: 0.7493 - loss: 0.7162 - val_accuracy: 0.8310 - val_loss: 0.4392 - learning_rate: 0.0010
# Epoch 11/400
# 682/682 - 65s - 96ms/step - accuracy: 0.7558 - loss: 0.6932 - val_accuracy: 0.8470 - val_loss: 0.3981 - learning_rate: 0.0010
# Epoch 12/400
# 682/682 - 64s - 94ms/step - accuracy: 0.7634 - loss: 0.6649 - val_accuracy: 0.8395 - val_loss: 0.4022 - learning_rate: 0.0010
# Epoch 13/400
# 682/682 - 65s - 96ms/step - accuracy: 0.7685 - loss: 0.6523 - val_accuracy: 0.8446 - val_loss: 0.3913 - learning_rate: 0.0010
# Epoch 14/400
# 682/682 - 67s - 99ms/step - accuracy: 0.7714 - loss: 0.6430 - val_accuracy: 0.8488 - val_loss: 0.3840 - learning_rate: 0.0010
# Epoch 15/400
# 682/682 - 67s - 98ms/step - accuracy: 0.7788 - loss: 0.6227 - val_accuracy: 0.8470 - val_loss: 0.3895 - learning_rate: 0.0010
# Epoch 16/400
# 682/682 - 66s - 97ms/step - accuracy: 0.7849 - loss: 0.5964 - val_accuracy: 0.8507 - val_loss: 0.3816 - learning_rate: 0.0010
# Epoch 17/400
# 682/682 - 65s - 95ms/step - accuracy: 0.7883 - loss: 0.5869 - val_accuracy: 0.8564 - val_loss: 0.3716 - learning_rate: 0.0010
# Epoch 18/400
# 682/682 - 64s - 93ms/step - accuracy: 0.7863 - loss: 0.5918 - val_accuracy: 0.8551 - val_loss: 0.3761 - learning_rate: 0.0010
# Epoch 19/400
# 682/682 - 63s - 92ms/step - accuracy: 0.7915 - loss: 0.5728 - val_accuracy: 0.8521 - val_loss: 0.3804 - learning_rate: 0.0010
# Epoch 20/400
# 682/682 - 63s - 92ms/step - accuracy: 0.7987 - loss: 0.5606 - val_accuracy: 0.8538 - val_loss: 0.3717 - learning_rate: 0.0010
# Epoch 21/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8036 - loss: 0.5405 - val_accuracy: 0.8598 - val_loss: 0.3628 - learning_rate: 8.5000e-04
# Epoch 22/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8054 - loss: 0.5400 - val_accuracy: 0.8565 - val_loss: 0.3634 - learning_rate: 8.5000e-04
# Epoch 23/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8062 - loss: 0.5268 - val_accuracy: 0.8626 - val_loss: 0.3612 - learning_rate: 8.5000e-04
# Epoch 24/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8120 - loss: 0.5202 - val_accuracy: 0.8608 - val_loss: 0.3629 - learning_rate: 8.5000e-04
# Epoch 25/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8130 - loss: 0.5141 - val_accuracy: 0.8630 - val_loss: 0.3569 - learning_rate: 8.5000e-04
# Epoch 26/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8189 - loss: 0.5032 - val_accuracy: 0.8617 - val_loss: 0.3592 - learning_rate: 8.5000e-04
# Epoch 27/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8205 - loss: 0.4957 - val_accuracy: 0.8611 - val_loss: 0.3601 - learning_rate: 8.5000e-04
# Epoch 28/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8181 - loss: 0.4984 - val_accuracy: 0.8633 - val_loss: 0.3583 - learning_rate: 8.5000e-04
# Epoch 29/400
# 682/682 - 66s - 97ms/step - accuracy: 0.8249 - loss: 0.4801 - val_accuracy: 0.8633 - val_loss: 0.3489 - learning_rate: 7.2250e-04
# Epoch 30/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8273 - loss: 0.4793 - val_accuracy: 0.8661 - val_loss: 0.3506 - learning_rate: 7.2250e-04
# Epoch 31/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8256 - loss: 0.4789 - val_accuracy: 0.8630 - val_loss: 0.3501 - learning_rate: 7.2250e-04
# Epoch 32/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8269 - loss: 0.4789 - val_accuracy: 0.8642 - val_loss: 0.3496 - learning_rate: 7.2250e-04
# Epoch 33/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8338 - loss: 0.4600 - val_accuracy: 0.8688 - val_loss: 0.3494 - learning_rate: 6.1413e-04
# Epoch 34/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8329 - loss: 0.4632 - val_accuracy: 0.8648 - val_loss: 0.3492 - learning_rate: 6.1413e-04
# Epoch 35/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8364 - loss: 0.4594 - val_accuracy: 0.8688 - val_loss: 0.3438 - learning_rate: 6.1413e-04
# Epoch 36/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8378 - loss: 0.4463 - val_accuracy: 0.8675 - val_loss: 0.3422 - learning_rate: 6.1413e-04
# Epoch 37/400
# 682/682 - 72s - 105ms/step - accuracy: 0.8354 - loss: 0.4512 - val_accuracy: 0.8716 - val_loss: 0.3413 - learning_rate: 6.1413e-04
# Epoch 38/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8380 - loss: 0.4430 - val_accuracy: 0.8650 - val_loss: 0.3419 - learning_rate: 6.1413e-04
# Epoch 39/400
# 682/682 - 62s - 92ms/step - accuracy: 0.8378 - loss: 0.4482 - val_accuracy: 0.8707 - val_loss: 0.3386 - learning_rate: 6.1413e-04
# Epoch 40/400
# 682/682 - 62s - 92ms/step - accuracy: 0.8411 - loss: 0.4367 - val_accuracy: 0.8694 - val_loss: 0.3460 - learning_rate: 6.1413e-04
# Epoch 41/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8438 - loss: 0.4361 - val_accuracy: 0.8712 - val_loss: 0.3431 - learning_rate: 6.1413e-04
# Epoch 42/400
# 682/682 - 61s - 90ms/step - accuracy: 0.8457 - loss: 0.4262 - val_accuracy: 0.8674 - val_loss: 0.3400 - learning_rate: 6.1413e-04
# Epoch 43/400
# 682/682 - 62s - 90ms/step - accuracy: 0.8462 - loss: 0.4266 - val_accuracy: 0.8721 - val_loss: 0.3387 - learning_rate: 5.2201e-04
# Epoch 44/400
# 682/682 - 62s - 92ms/step - accuracy: 0.8442 - loss: 0.4301 - val_accuracy: 0.8716 - val_loss: 0.3384 - learning_rate: 5.2201e-04
# Epoch 45/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8475 - loss: 0.4222 - val_accuracy: 0.8685 - val_loss: 0.3404 - learning_rate: 5.2201e-04
# Epoch 46/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8441 - loss: 0.4180 - val_accuracy: 0.8707 - val_loss: 0.3389 - learning_rate: 5.2201e-04
# Epoch 47/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8510 - loss: 0.4154 - val_accuracy: 0.8742 - val_loss: 0.3349 - learning_rate: 5.2201e-04
# Epoch 48/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8503 - loss: 0.4105 - val_accuracy: 0.8688 - val_loss: 0.3411 - learning_rate: 5.2201e-04
# Epoch 49/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8495 - loss: 0.4130 - val_accuracy: 0.8725 - val_loss: 0.3415 - learning_rate: 5.2201e-04
# Epoch 50/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8499 - loss: 0.4142 - val_accuracy: 0.8738 - val_loss: 0.3356 - learning_rate: 5.2201e-04
# Epoch 51/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8485 - loss: 0.4143 - val_accuracy: 0.8716 - val_loss: 0.3352 - learning_rate: 4.4371e-04
# Epoch 52/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8543 - loss: 0.3984 - val_accuracy: 0.8723 - val_loss: 0.3365 - learning_rate: 4.4371e-04
# Epoch 53/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8538 - loss: 0.4057 - val_accuracy: 0.8743 - val_loss: 0.3370 - learning_rate: 4.4371e-04
# Epoch 54/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8560 - loss: 0.3925 - val_accuracy: 0.8764 - val_loss: 0.3382 - learning_rate: 3.7715e-04
# Epoch 55/400
# 682/682 - 65s - 95ms/step - accuracy: 0.8540 - loss: 0.4015 - val_accuracy: 0.8764 - val_loss: 0.3342 - learning_rate: 3.7715e-04
# Epoch 56/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8575 - loss: 0.3945 - val_accuracy: 0.8760 - val_loss: 0.3374 - learning_rate: 3.7715e-04
# Epoch 57/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8572 - loss: 0.3934 - val_accuracy: 0.8727 - val_loss: 0.3375 - learning_rate: 3.7715e-04
# Epoch 58/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8600 - loss: 0.3926 - val_accuracy: 0.8776 - val_loss: 0.3336 - learning_rate: 3.7715e-04
# Epoch 59/400
# 682/682 - 62s - 91ms/step - accuracy: 0.8561 - loss: 0.3915 - val_accuracy: 0.8743 - val_loss: 0.3387 - learning_rate: 3.7715e-04
# Epoch 60/400
# 682/682 - 62s - 91ms/step - accuracy: 0.8595 - loss: 0.3889 - val_accuracy: 0.8775 - val_loss: 0.3327 - learning_rate: 3.7715e-04
# Epoch 61/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8610 - loss: 0.3848 - val_accuracy: 0.8782 - val_loss: 0.3320 - learning_rate: 3.7715e-04
# Epoch 62/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8603 - loss: 0.3863 - val_accuracy: 0.8760 - val_loss: 0.3334 - learning_rate: 3.7715e-04
# Epoch 63/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8636 - loss: 0.3813 - val_accuracy: 0.8723 - val_loss: 0.3341 - learning_rate: 3.7715e-04
# Epoch 64/400
# 682/682 - 65s - 95ms/step - accuracy: 0.8597 - loss: 0.3909 - val_accuracy: 0.8762 - val_loss: 0.3323 - learning_rate: 3.7715e-04
# Epoch 65/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8617 - loss: 0.3763 - val_accuracy: 0.8773 - val_loss: 0.3296 - learning_rate: 3.2058e-04
# Epoch 66/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8618 - loss: 0.3794 - val_accuracy: 0.8740 - val_loss: 0.3303 - learning_rate: 3.2058e-04
# Epoch 67/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8652 - loss: 0.3725 - val_accuracy: 0.8762 - val_loss: 0.3316 - learning_rate: 3.2058e-04
# Epoch 68/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8627 - loss: 0.3815 - val_accuracy: 0.8778 - val_loss: 0.3317 - learning_rate: 3.2058e-04
# Epoch 69/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8632 - loss: 0.3712 - val_accuracy: 0.8782 - val_loss: 0.3342 - learning_rate: 2.7249e-04
# Epoch 70/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8673 - loss: 0.3625 - val_accuracy: 0.8775 - val_loss: 0.3373 - learning_rate: 2.7249e-04
# Epoch 71/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8647 - loss: 0.3676 - val_accuracy: 0.8751 - val_loss: 0.3355 - learning_rate: 2.7249e-04
# Epoch 72/400
# 682/682 - 63s - 92ms/step - accuracy: 0.8674 - loss: 0.3641 - val_accuracy: 0.8773 - val_loss: 0.3295 - learning_rate: 2.3162e-04
# Epoch 73/400
# 682/682 - 63s - 93ms/step - accuracy: 0.8668 - loss: 0.3636 - val_accuracy: 0.8775 - val_loss: 0.3278 - learning_rate: 2.3162e-04
# Epoch 74/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8682 - loss: 0.3594 - val_accuracy: 0.8808 - val_loss: 0.3318 - learning_rate: 2.3162e-04
# Epoch 75/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8668 - loss: 0.3696 - val_accuracy: 0.8778 - val_loss: 0.3318 - learning_rate: 2.3162e-04
# Epoch 76/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8677 - loss: 0.3650 - val_accuracy: 0.8756 - val_loss: 0.3276 - learning_rate: 2.3162e-04
# Epoch 77/400
# 682/682 - 62s - 90ms/step - accuracy: 0.8723 - loss: 0.3610 - val_accuracy: 0.8767 - val_loss: 0.3295 - learning_rate: 2.3162e-04
# Epoch 78/400
# 682/682 - 60s - 88ms/step - accuracy: 0.8616 - loss: 0.3724 - val_accuracy: 0.8784 - val_loss: 0.3318 - learning_rate: 2.3162e-04
# Epoch 79/400
# 682/682 - 60s - 88ms/step - accuracy: 0.8692 - loss: 0.3602 - val_accuracy: 0.8786 - val_loss: 0.3301 - learning_rate: 2.3162e-04
# Epoch 80/400
# 682/682 - 62s - 91ms/step - accuracy: 0.8712 - loss: 0.3601 - val_accuracy: 0.8793 - val_loss: 0.3315 - learning_rate: 1.9687e-04
# Epoch 81/400
# 682/682 - 67s - 99ms/step - accuracy: 0.8703 - loss: 0.3585 - val_accuracy: 0.8776 - val_loss: 0.3291 - learning_rate: 1.9687e-04
# Epoch 82/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8668 - loss: 0.3584 - val_accuracy: 0.8798 - val_loss: 0.3290 - learning_rate: 1.9687e-04
# Epoch 83/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8725 - loss: 0.3529 - val_accuracy: 0.8802 - val_loss: 0.3332 - learning_rate: 1.6734e-04
# Epoch 84/400
# 682/682 - 64s - 93ms/step - accuracy: 0.8676 - loss: 0.3592 - val_accuracy: 0.8786 - val_loss: 0.3290 - learning_rate: 1.6734e-04
# Epoch 85/400
# 682/682 - 64s - 94ms/step - accuracy: 0.8727 - loss: 0.3564 - val_accuracy: 0.8780 - val_loss: 0.3286 - learning_rate: 1.6734e-04
# Epoch 86/400
# 682/682 - 65s - 96ms/step - accuracy: 0.8709 - loss: 0.3494 - val_accuracy: 0.8786 - val_loss: 0.3313 - learning_rate: 1.4224e-04
# Epoch 87/400
# 682/682 - 68s - 100ms/step - accuracy: 0.8746 - loss: 0.3481 - val_accuracy: 0.8778 - val_loss: 0.3316 - learning_rate: 1.4224e-04
# Epoch 88/400
# 682/682 - 68s - 100ms/step - accuracy: 0.8754 - loss: 0.3470 - val_accuracy: 0.8773 - val_loss: 0.3297 - learning_rate: 1.4224e-04
# Epoch 89/400
# 682/682 - 68s - 100ms/step - accuracy: 0.8735 - loss: 0.3508 - val_accuracy: 0.8764 - val_loss: 0.3292 - learning_rate: 1.2091e-04
# Epoch 90/400
# 682/682 - 66s - 96ms/step - accuracy: 0.8725 - loss: 0.3484 - val_accuracy: 0.8780 - val_loss: 0.3289 - learning_rate: 1.2091e-04
# Epoch 91/400
# 682/682 - 66s - 96ms/step - accuracy: 0.8718 - loss: 0.3459 - val_accuracy: 0.8776 - val_loss: 0.3305 - learning_rate: 1.2091e-04
# Epoch 92/400
# 682/682 - 66s - 97ms/step - accuracy: 0.8734 - loss: 0.3513 - val_accuracy: 0.8758 - val_loss: 0.3277 - learning_rate: 1.0277e-04
# Epoch 93/400
# 682/682 - 67s - 99ms/step - accuracy: 0.8733 - loss: 0.3504 - val_accuracy: 0.8782 - val_loss: 0.3298 - learning_rate: 1.0277e-04
# Epoch 94/400
# 682/682 - 66s - 97ms/step - accuracy: 0.8786 - loss: 0.3389 - val_accuracy: 0.8778 - val_loss: 0.3301 - learning_rate: 1.0277e-04
# Epoch 95/400
# 682/682 - 68s - 99ms/step - accuracy: 0.8771 - loss: 0.3417 - val_accuracy: 0.8784 - val_loss: 0.3298 - learning_rate: 8.7354e-05
# Epoch 96/400
# 682/682 - 67s - 98ms/step - accuracy: 0.8733 - loss: 0.3403 - val_accuracy: 0.8775 - val_loss: 0.3292 - learning_rate: 8.7354e-05
# Epoch 97/400
# 682/682 - 67s - 99ms/step - accuracy: 0.8741 - loss: 0.3460 - val_accuracy: 0.8782 - val_loss: 0.3282 - learning_rate: 8.7354e-05
# Epoch 98/400
# 682/682 - 66s - 97ms/step - accuracy: 0.8732 - loss: 0.3433 - val_accuracy: 0.8776 - val_loss: 0.3288 - learning_rate: 7.4251e-05
# Epoch 99/400
# 682/682 - 67s - 99ms/step - accuracy: 0.8750 - loss: 0.3435 - val_accuracy: 0.8780 - val_loss: 0.3291 - learning_rate: 7.4251e-05
# Epoch 100/400
# 682/682 - 66s - 97ms/step - accuracy: 0.8798 - loss: 0.3377 - val_accuracy: 0.8791 - val_loss: 0.3296 - learning_rate: 7.4251e-05
# Epoch 101/400
# 682/682 - 67s - 99ms/step - accuracy: 0.8792 - loss: 0.3375 - val_accuracy: 0.8776 - val_loss: 0.3303 - learning_rate: 6.3113e-05
# INFO:tensorflow:Assets written to: output/tmp/dig-class100-s2/assets
# INFO:tensorflow:Assets written to: output/tmp/dig-class100-s2/assets
# Saved artifact at 'output/tmp/dig-class100-s2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 32, 20, 3), dtype=tf.float32, name='keras_tensor_5')
# Output Type:
#   TensorSpec(shape=(None, 100), dtype=tf.float32, name=None)
# Captures:
#   13437716256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437715552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437716784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437716608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437727168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437727872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437728048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437728224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437727520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437726992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437729280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437730160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437729808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437729632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437729104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437729984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437730336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   13437730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492708608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492708784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492707904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492708432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492709664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492710544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492710192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   16492711072: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# ### Validate on all digit meter
#
# Because of the small dataset of meter digits all meter digits are used for validation. The first false predicted will be shown in the diagram.

# %%
false_predicted_files = predict_meter_digits(model, x_data=xz_data, y_data=yz_data, f_data=fz_data, 
                                            max_delta=0.21)
fpf = pd.DataFrame(false_predicted_files)

# the csv can be used with collectmeterdigits to fix labels
# python3 -m collectmeterdigits --labelfile=output/tmp/dig-class100-s2_false_predicted.csv
fpf.to_csv(output_tmp_dir + model_filename + '_false_predicted.csv')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tf217/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# Tested images: 27253. 43 false predicted. Accuracy is: 0.9984221920522511

# %%
from dataclasses import dataclass
from b2n.models.prune_quantize import  quantization_default
from  tensorflow import keras

# prune the model
# pruning reduces the accurracy 
#model_pruned = prune(model=model, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test)

# quanitize and save the model
tflite_model = quantization_default(model_filename=output_tmp_dir + model_filename, 
                            x_train=x_test)
# save the model
filename=output_dir + model_filename + "_" + date_time + "_q_neu.tflite"                                                     
open( filename, "wb").write(tflite_model)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1762287866.587023 27679764 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1762287866.587288 27679764 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# 2025-11-04 21:24:26.590013: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: output/tmp/dig-class100-s2
# 2025-11-04 21:24:26.591151: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-11-04 21:24:26.591157: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: output/tmp/dig-class100-s2
# 2025-11-04 21:24:26.603430: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2025-11-04 21:24:26.605687: I tensorflow/cc/saved_model/loader.cc:234] Restoring SavedModel bundle.
# 2025-11-04 21:24:26.647249: I tensorflow/cc/saved_model/loader.cc:218] Running initialization op on SavedModel bundle at path: output/tmp/dig-class100-s2
# 2025-11-04 21:24:26.654774: I tensorflow/cc/saved_model/loader.cc:317] SavedModel load for tags { serve }; Status: success: OK. Took 64761 microseconds.
# 2025-11-04 21:24:26.689099: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-04 21:24:27.221686: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# 226648
